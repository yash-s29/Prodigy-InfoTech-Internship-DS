# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('population.csv')

# %%
df.head()
# Out:
#            Country Name Country Code     Indicator Name Indicator Code  \
# 0               Albania          ALB  Population, total    SP.POP.TOTL
# 1               Andorra          AND  Population, total    SP.POP.TOTL
# 2            Arab World          ARB  Population, total    SP.POP.TOTL
# 3  United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 4             Argentina          ARG  Population, total    SP.POP.TOTL
#
#        1960      1961      1962       1963       1964       1965  ...  \
# 0   1608800   1659800   1711319    1762621    1814135    1864791  ...
# 1      9443     10216     11014      11839      12690      13563  ...
# 2  93359407  95760348  98268683  100892507  103618568  106444103  ...
# 3    133426    140984    148877     157006     165305     173797  ...
# 4  20349744  20680653  21020359   21364017   21708487   22053661  ...
#
#         2013       2014       2015       2016       2017       2018  \
# ...

# %%
df.tail(10)
# Out:
#                                      Country Name Country Code  \
# 120                                       Lebanon          LBN
# 121                                       Liberia          LBR
# 122                                         Libya          LBY
# 123                                     St. Lucia          LCA
# 124                     Latin America & Caribbean          LCN
# 125  Least developed countries: UN classification          LDC
# 126                                 Liechtenstein          LIE
# 127                                     Sri Lanka          LKA
# 128                     Late-demographic dividend          LTE
# 129                                     Lithuania          LTU
#
#         Indicator Name Indicator Code       1960       1961       1962  \
# 120  Population, total    SP.POP.TOTL    1137026    1165005    1194085
# 121  Population, total    SP.POP.TOTL    1426986    1478760    1535157
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df.shape
# Out:
# (130, 67)

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# Length: 67, dtype: int64

# %%
df.dtypes
# Out:
# Country Name      object
# Country Code      object
# Indicator Name    object
# Indicator Code    object
# 1960               int64
#                    ...
# 2018               int64
# 2019               int64
# 2020               int64
# 2021               int64
# 2022               int64
# Length: 67, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    130 non-null    object
#  1   Country Code    130 non-null    object
#  2   Indicator Name  130 non-null    object
#  3   Indicator Code  130 non-null    object
#  4   1960            130 non-null    int64
#  5   1961            130 non-null    int64
#  6   1962            130 non-null    int64
#  7   1963            130 non-null    int64
#  8   1964            130 non-null    int64
#  9   1965            130 non-null    int64
#  10  1966            130 non-null    int64
#  11  1967            130 non-null    int64
#  12  1968            130 non-null    int64
#  13  1969            130 non-null    int64
#  14  1970            130 non-null    int64
#  15  1971            130 non-null    int64
#  16  1972            130 non-null    int64
# ...

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(14, 6))

# %%
plt.subplot(1, 2, 1)
sns.histplot(df['2022'], kde=True, color='skyblue', bins=20)
plt.title('Distribution of Population in 2022 (Histogram)')
plt.xlabel('Population in 2022')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(12, 7))
year = '2022'
sns.barplot(data=top_10, x='Country Name', y=year, palette='viridis', hue='Country Name', legend=False)
plt.title(f'Top 10 Countries/Regions by Population in {year}', fontsize=16)
plt.xlabel('Country Name', fontsize=12)
plt.ylabel('Population Count', fontsize=12)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.savefig('vertical_bar_chart.png')
plt.show()
